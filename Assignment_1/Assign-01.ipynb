# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/shrav/Downloads/DSBDA_Practicles/Assignment_1/heart-treat.csv")

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
X=df.drop("HeartDisease",axis=1)
Y=df.HeartDisease
X.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up

# %%
plt.scatter(df.Cholesterol,df.HeartDisease,color='red')
plt.xlabel("Cholestrol")
plt.ylabel("HeartDisease or not")
# Out:
# Text(0, 0.5, 'HeartDisease or not')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
s=df.drop("Sex",axis=1)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.drop("Sex",axis=1)
# Out:
#      Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40           ATA        140          289          0     Normal    172
# 1     49           NAP        160          180          0     Normal    156
# 2     37           ATA        130          283          0         ST     98
# 3     48           ASY        138          214          0     Normal    108
# 4     54           NAP        150          195          0     Normal    122
# ..   ...           ...        ...          ...        ...        ...    ...
# 913   45            TA        110          264          0     Normal    132
# 914   68           ASY        144          193          1     Normal    141
# 915   57           ASY        130          131          0     Normal    115
# 916   57           ATA        130          236          0        LVH    174
# 917   38           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                N      0.0       Up             0
# 1                N      1.0     Flat             1
# 2                N      0.0       Up             0
# 3                Y      1.5     Flat             1
# 4                N      0.0       Up             0
# ..             ...      ...      ...           ...
# 913              N      1.2     Flat             1
# 914              N      3.4     Flat             1
# 915              Y      1.2     Flat             1
# 916              N      0.0     Flat             1
# 917              N      0.0       Up             0
#
# [918 rows x 11 columns]

# %%
df.drop("ChestPainType",axis=1)
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40   M        140          289          0     Normal    172
# 1     49   F        160          180          0     Normal    156
# 2     37   M        130          283          0         ST     98
# 3     48   F        138          214          0     Normal    108
# 4     54   M        150          195          0     Normal    122
# ..   ...  ..        ...          ...        ...        ...    ...
# 913   45   M        110          264          0     Normal    132
# 914   68   M        144          193          1     Normal    141
# 915   57   M        130          131          0     Normal    115
# 916   57   F        130          236          0        LVH    174
# 917   38   M        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                N      0.0       Up             0
# 1                N      1.0     Flat             1
# 2                N      0.0       Up             0
# 3                Y      1.5     Flat             1
# 4                N      0.0       Up             0
# ..             ...      ...      ...           ...
# 913              N      1.2     Flat             1
# 914              N      3.4     Flat             1
# 915              Y      1.2     Flat             1
# 916              N      0.0     Flat             1
# 917              N      0.0       Up             0
#
# [918 rows x 11 columns]

# %%
X=df.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],axis=1)
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
# [918 rows x 7 columns]

# %%
model.fit(X,Y)
# Out:
# C:\My Files\Files\All programing apps\Ananconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Acuuracy score is: ",accuracy_score(Y,y_pred))
# Out:
# Acuuracy score is:  1.0

# %%
output=model.predict([[30,120,300,1,150,1.0,1]])
def prediction(p):
    if(p[0]==0):
        print("Patient is not HeartDiseased")
    else:
        print("Patient is HeartDiseased")
# Out:
# C:\My Files\Files\All programing apps\Ananconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
df['Oldpeak']=df['Oldpeak'].astype('int') #Float into int

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N        0       Up             0
# 1      156              N        1     Flat             1
# 2       98              N        0       Up             0
# 3      108              Y        1     Flat             1
# 4      122              N        0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N        1     Flat             1
# 914    141              N        3     Flat             1
# 915    115              Y        1     Flat             1
# 916    174              N        0     Flat             1
# 917    173              N        0       Up             0
#
# [918 rows x 12 columns]

# %%
prediction(output)
# Out:
# Patient is HeartDiseased

# %% [markdown]
# print("Acuuracy score is: ",accuracy_score(Y,y_pred))

# %%
print("Acuuracy score is: ",accuracy_score(Y,y_pred))
# Out:
# Acuuracy score is:  1.0

# %% [markdown]
# # Converting Categorical values into quantitive variables

# %%
pd.get_dummies(df,dtype='int')
